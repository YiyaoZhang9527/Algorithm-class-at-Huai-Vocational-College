# %%
import numpy as np


# plt.rcParams.update({
#     "font.family": "serif",
#     # Use LaTeX default serif font.
#     "font.serif": [],
#     # Use specific cursive fonts.
#     "font.cursive": ["Comic Neue", "Comic Sans MS"],
# })
# import matplotlib as mpl
# mpl.font_manager.fontManager.addfont("/Users/magu/anaconda3/envs/TS_ENV_38_add_AKshare/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/SimHei.ttf")
# plt.rcParams['font.sans-serif'] = ['SimHei'] 

import platform
import matplotlib.pyplot as plt

system = platform.system()
if system == "Linux":
    plt.rcParams['font.sans-serif'] = ["Noto Sans CJK JP"]
elif system == "Darwin":
    plt.rcParams['font.sans-serif'] = ["Kaiti SC"]
plt.rcParams['axes.unicode_minus'] = False
#plt.rcParams['font.sans-serif'] = ["Kaiti SC"]#["Arial Unicode MS"]#["Yuppy TC"] # mac os 中文字体



import matplotlib.pyplot as plt

x = list(range(5))
y = list(range(1,10,2))
plt.figure(figsize=(16,9))
plt.plot(x,y)
plt.title("中文显示测试",fontsize=40)
plt.xlabel('x轴数据',fontsize = 20)
plt.ylabel('y轴数据',fontsize = 20)
plt.show()

# %%
# Out:
# 'Darwin'

# %%
# from matplotlib.font_manager import FontManager
# fm = FontManager()
# mat_fonts = set(f.name for f in fm.ttflist)
# n = 0
# for mat_font in mat_fonts:
#     n += 1
#     if mat_font in ["SimHei","Arial Unicode MS"]:
#         print(f"[{n}]:{mat_font}")
        
        
# list(mat_fonts)[169]

# %% [markdown]
# ## 查看当前环境有哪些字体可以显示中文

# %%
import warnings
warnings.filterwarnings('ignore')
from matplotlib.font_manager import FontManager
fm = FontManager()
mat_fonts = set(f.name for f in fm.ttflist)
n = 0
for mat_font in mat_fonts:
    n += 1
    print(f"当前序号:[{n}]<->当前字体:[{mat_font}]")
    plt.rcParams['font.sans-serif'] = [mat_font] # mac os 中文字体
    plt.rcParams['axes.unicode_minus'] = False
    plt.figure(figsize=(1,1))
    plt.title("-中文测试是否能用")
    plt.xlabel('x轴数据')
    
    plt.ylabel('y轴数据')
    plt.show()
# Out:
# 当前序号:[1]<->当前字体:[Nimbus Mono PS]
# 当前序号:[2]<->当前字体:[Lohit Gujarati]
# 当前序号:[3]<->当前字体:[MathJax_Caligraphic]
# 当前序号:[4]<->当前字体:[Droid Sans Fallback]
# 当前序号:[5]<->当前字体:[KacstDigital]
# 当前序号:[6]<->当前字体:[MathJax_Fraktur]
# 当前序号:[7]<->当前字体:[Webdings]
# 当前序号:[8]<->当前字体:[DejaVu Serif]
# 当前序号:[9]<->当前字体:[C059]
# 当前序号:[10]<->当前字体:[cmss10]
# 当前序号:[11]<->当前字体:[KacstQurn]
# 当前序号:[12]<->当前字体:[Z003]
# 当前序号:[13]<->当前字体:[Loma]
# 当前序号:[14]<->当前字体:[RaghuMalayalamSans]
# 当前序号:[15]<->当前字体:[Gayathri]
# 当前序号:[16]<->当前字体:[mry_KacstQurn]
# 当前序号:[17]<->当前字体:[Phetsarath OT]
# 当前序号:[18]<->当前字体:[Mukti]
# 当前序号:[19]<->当前字体:[Pothana2000]
# 当前序号:[20]<->当前字体:[MathJax_Math]
# 当前序号:[21]<->当前字体:[Quicksand Medium]
# 当前序号:[22]<->当前字体:[msbm10]
# 当前序号:[23]<->当前字体:[Noto Mono]
# 当前序号:[24]<->当前字体:[Lohit Odia]
# 当前序号:[25]<->当前字体:[Meera]
# 当前序号:[26]<->当前字体:[Lohit Malayalam]
# 当前序号:[27]<->当前字体:[KacstOne]
# 当前序号:[28]<->当前字体:[League Spartan]
# 当前序号:[29]<->当前字体:[AnjaliOldLipi]
# 当前序号:[30]<->当前字体:[Padauk]
# 当前序号:[31]<->当前字体:[MathJax_AMS]
# 当前序号:[32]<->当前字体:[Liberation Mono]
# 当前序号:[33]<->当前字体:[Potti Sreeramulu]
# 当前序号:[34]<->当前字体:[rsfs10]
# 当前序号:[35]<->当前字体:[Keraleeyam]
# 当前序号:[36]<->当前字体:[Liberation Serif]
# 当前序号:[37]<->当前字体:[ori1Uni]
# 当前序号:[38]<->当前字体:[STIXGeneral]
# 当前序号:[39]<->当前字体:[Lohit Tamil]
# 当前序号:[40]<->当前字体:[Samyak Malayalam]
# 当前序号:[41]<->当前字体:[Georgia]
# 当前序号:[42]<->当前字体:[Rasa]
# 当前序号:[43]<->当前字体:[KacstScreen]
# 当前序号:[44]<->当前字体:[Timmana]
# 当前序号:[45]<->当前字体:[FreeMono]
# 当前序号:[46]<->当前字体:[Yrsa]
# 当前序号:[47]<->当前字体:[MathJax_Size2]
# 当前序号:[48]<->当前字体:[MathJax_WinIE6]
# 当前序号:[49]<->当前字体:[AR PL UMing CN]
# 当前序号:[50]<->当前字体:[Gubbi]
# 当前序号:[51]<->当前字体:[KacstTitle]
# 当前序号:[52]<->当前字体:[Lohit Bengali]
# 当前序号:[53]<->当前字体:[KacstPoster]
# 当前序号:[54]<->当前字体:[Chilanka]
# 当前序号:[55]<->当前字体:[Uroob]
# 当前序号:[56]<->当前字体:[Courier New]
# 当前序号:[57]<->当前字体:[Rachana]
# 当前序号:[58]<->当前字体:[Lohit Kannada]
# 当前序号:[59]<->当前字体:[Rekha]
# 当前序号:[60]<->当前字体:[Ani]
# 当前序号:[61]<->当前字体:[Nimbus Sans Narrow]
# 当前序号:[62]<->当前字体:[Norasi]
# 当前序号:[63]<->当前字体:[DejaVu Sans Display]
# 当前序号:[64]<->当前字体:[Tlwg Typewriter]
# 当前序号:[65]<->当前字体:[Waree]
# 当前序号:[66]<->当前字体:[Sahadeva]
# 当前序号:[67]<->当前字体:[Noto Sans Mono]
# 当前序号:[68]<->当前字体:[NTR]
# 当前序号:[69]<->当前字体:[Ubuntu Mono]
# 当前序号:[70]<->当前字体:[MathJax_Size1]
# 当前序号:[71]<->当前字体:[MathJax_Size3]
# 当前序号:[72]<->当前字体:[STIXSizeFourSym]
# 当前序号:[73]<->当前字体:[STIXNonUnicode]
# 当前序号:[74]<->当前字体:[LakkiReddy]
# 当前序号:[75]<->当前字体:[Purisa]
# 当前序号:[76]<->当前字体:[FreeSerif]
# 当前序号:[77]<->当前字体:[Navilu]
# 当前序号:[78]<->当前字体:[URW Gothic]
# 当前序号:[79]<->当前字体:[Manjari]
# 当前序号:[80]<->当前字体:[padmaa]
# 当前序号:[81]<->当前字体:[Arial]
# 当前序号:[82]<->当前字体:[KacstDecorative]
# 当前序号:[83]<->当前字体:[cmsy10]
# 当前序号:[84]<->当前字体:[Quicksand]
# 当前序号:[85]<->当前字体:[Pagul]
# 当前序号:[86]<->当前字体:[KacstBook]
# 当前序号:[87]<->当前字体:[MathJax_Main]
# 当前序号:[88]<->当前字体:[Verdana]
# 当前序号:[89]<->当前字体:[STIXSizeFiveSym]
# 当前序号:[90]<->当前字体:[Lohit Devanagari]
# 当前序号:[91]<->当前字体:[Impact]
# 当前序号:[92]<->当前字体:[Liberation Sans]
# 当前序号:[93]<->当前字体:[Ubuntu]
# 当前序号:[94]<->当前字体:[MathJax_SansSerif]
# 当前序号:[95]<->当前字体:[Umpush]
# 当前序号:[96]<->当前字体:[Lohit Assamese]
# 当前序号:[97]<->当前字体:[MathJax_Typewriter]
# 当前序号:[98]<->当前字体:[Kalimati]
# 当前序号:[99]<->当前字体:[D050000L]
# 当前序号:[100]<->当前字体:[Laksaman]
# 当前序号:[101]<->当前字体:[Likhan]
# 当前序号:[102]<->当前字体:[Karumbi]
# 当前序号:[103]<->当前字体:[Suravaram]
# 当前序号:[104]<->当前字体:[Samyak Tamil]
# 当前序号:[105]<->当前字体:[Gargi]
# 当前序号:[106]<->当前字体:[aakar]
# 当前序号:[107]<->当前字体:[Samanata]
# 当前序号:[108]<->当前字体:[Mitra ]
# 当前序号:[109]<->当前字体:[Tibetan Machine Uni]
# 当前序号:[110]<->当前字体:[Chandas]
# 当前序号:[111]<->当前字体:[eufm10]
# 当前序号:[112]<->当前字体:[KacstOffice]
# 当前序号:[113]<->当前字体:[TenaliRamakrishna]
# 当前序号:[114]<->当前字体:[MathJax_Vector-Bold]
# 当前序号:[115]<->当前字体:[FreeSans]
# 当前序号:[116]<->当前字体:[STIXSizeOneSym]
# 当前序号:[117]<->当前字体:[Ponnala]
# 当前序号:[118]<->当前字体:[NATS]
# 当前序号:[119]<->当前字体:[Samyak Devanagari]
# 当前序号:[120]<->当前字体:[Kalapi]
# 当前序号:[121]<->当前字体:[Nakula]
# 当前序号:[122]<->当前字体:[Trebuchet MS]
# 当前序号:[123]<->当前字体:[Vemana2000]
# 当前序号:[124]<->当前字体:[Dhurjati]
# 当前序号:[125]<->当前字体:[Kinnari]
# 当前序号:[126]<->当前字体:[cmmi10]
# 当前序号:[127]<->当前字体:[esint10]
# 当前序号:[128]<->当前字体:[cmtt10]
# 当前序号:[129]<->当前字体:[Tlwg Mono]
# 当前序号:[130]<->当前字体:[Mandali]
# 当前序号:[131]<->当前字体:[Mallanna]
# 当前序号:[132]<->当前字体:[Quicksand Light]
# 当前序号:[133]<->当前字体:[Peddana]
# 当前序号:[134]<->当前字体:[stmary10]
# 当前序号:[135]<->当前字体:[Nimbus Roman]
# 当前序号:[136]<->当前字体:[Standard Symbols PS]
# 当前序号:[137]<->当前字体:[cmb10]
# 当前序号:[138]<->当前字体:[Liberation Sans Narrow]
# 当前序号:[139]<->当前字体:[Gidugu]
# 当前序号:[140]<->当前字体:[wasy10]
# 当前序号:[141]<->当前字体:[KacstFarsi]
# 当前序号:[142]<->当前字体:[KacstLetter]
# 当前序号:[143]<->当前字体:[padmaa-Bold.1.1]
# 当前序号:[144]<->当前字体:[KacstArt]
# 当前序号:[145]<->当前字体:[STIXSizeThreeSym]
# 当前序号:[146]<->当前字体:[DejaVu Serif Display]
# 当前序号:[147]<->当前字体:[Lohit Telugu]
# 当前序号:[148]<->当前字体:[Syamala Ramana]
# 当前序号:[149]<->当前字体:[Gurajada]
# 当前序号:[150]<->当前字体:[Padauk Book]
# 当前序号:[151]<->当前字体:[LKLUG]
# 当前序号:[152]<->当前字体:[Sawasdee]
# 当前序号:[153]<->当前字体:[Tlwg Typo]
# 当前序号:[154]<->当前字体:[Comic Sans MS]
# 当前序号:[155]<->当前字体:[Noto Sans CJK JP]
# 当前序号:[156]<->当前字体:[Abyssinica SIL]
# 当前序号:[157]<->当前字体:[OpenSymbol]
# 当前序号:[158]<->当前字体:[Tlwg Typist]
# 当前序号:[159]<->当前字体:[Ubuntu Condensed]
# 当前序号:[160]<->当前字体:[KacstTitleL]
# 当前序号:[161]<->当前字体:[Khmer OS System]
# 当前序号:[162]<->当前字体:[DejaVu Sans]
# 当前序号:[163]<->当前字体:[MathJax_WinChrome]
# 当前序号:[164]<->当前字体:[dsrom10]
# 当前序号:[165]<->当前字体:[cmex10]
# 当前序号:[166]<->当前字体:[Khmer OS]
# 当前序号:[167]<->当前字体:[P052]
# 当前序号:[168]<->当前字体:[Sree Krushnadevaraya]
# 当前序号:[169]<->当前字体:[cmr10]
# 当前序号:[170]<->当前字体:[Garuda]
# 当前序号:[171]<->当前字体:[MathJax_Script]
# 当前序号:[172]<->当前字体:[KacstPen]
# 当前序号:[173]<->当前字体:[Andale Mono]
# 当前序号:[174]<->当前字体:[DejaVu Sans Mono]
# 当前序号:[175]<->当前字体:[Nimbus Sans]
# 当前序号:[176]<->当前字体:[Jamrul]
# 当前序号:[177]<->当前字体:[KacstNaskh]
# 当前序号:[178]<->当前字体:[Lohit Tamil Classical]
# 当前序号:[179]<->当前字体:[Ramaraja]
# 当前序号:[180]<->当前字体:[RaviPrakash]
# 当前序号:[181]<->当前字体:[Suruma]
# 当前序号:[182]<->当前字体:[MathJax_Vector]
# 当前序号:[183]<->当前字体:[STIXSizeTwoSym]
# 当前序号:[184]<->当前字体:[Saab]
# 当前序号:[185]<->当前字体:[Ramabhadra]
# 当前序号:[186]<->当前字体:[Arial Black]
# 当前序号:[187]<->当前字体:[Noto Serif CJK JP]
# 当前序号:[188]<->当前字体:[msam10]
# 当前序号:[189]<->当前字体:[Lohit Gurmukhi]
# 当前序号:[190]<->当前字体:[AR PL UKai CN]
# 当前序号:[191]<->当前字体:[URW Bookman]
# 当前序号:[192]<->当前字体:[Sarai]
# 当前序号:[193]<->当前字体:[Times New Roman]
# 当前序号:[194]<->当前字体:[Dyuthi]
# 当前序号:[195]<->当前字体:[Samyak Gujarati]
# 当前序号:[196]<->当前字体:[MathJax_Size4]
# 当前序号:[197]<->当前字体:[Lato]
# 当前序号:[198]<->当前字体:[Suranna]

# %%
import matplotlib    
print(matplotlib.matplotlib_fname())

import matplotlib
print(matplotlib.get_cachedir())
# Out:
# /home/zhangmanman/anaconda3/lib/python3.9/site-packages/matplotlib/mpl-data/matplotlibrc
# /home/zhangmanman/.cache/matplotlib
