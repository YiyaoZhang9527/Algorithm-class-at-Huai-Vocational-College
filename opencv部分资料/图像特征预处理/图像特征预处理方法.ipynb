# %% [markdown]
# ### 图像读取

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

x = np.arange(-1,1.001,0.001)
plt.figure(figsize=(16,10))
plt.scatter(np.arange(0,x.size),x)
plt.show()
