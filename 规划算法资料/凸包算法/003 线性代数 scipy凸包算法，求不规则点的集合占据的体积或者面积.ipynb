# %%
# -*- coding: utf-8 -*-
from scipy.spatial import ConvexHull
import numpy as np
import matplotlib.pyplot as plt
##########scipy 凸包################
points = np.random.rand(30, 2)
hull = ConvexHull(points)
{'所有点':hull.points,'边界':hull.max_bound,'纬度':hull.ndim,'计算点数量':hull.npoints,'a':hull.nsimplex,'凸壳单面形成点的指数':hull.simplices,'面积':hull.area,'形成小面的超平面方程':hull.equations,'体积':hull.volume}
# Out:
# {'所有点': array([[0.32732107, 0.28026933],
#         [0.73046934, 0.33946118],
#         [0.09965924, 0.32573858],
#         [0.95914151, 0.44419267],
#         [0.79441597, 0.18989562],
#         [0.44931062, 0.71511796],
#         [0.61764209, 0.85048549],
#         [0.79096031, 0.23224959],
#         [0.99971494, 0.18786762],
#         [0.55824704, 0.65730121],
#         [0.50676697, 0.42322555],
#         [0.62443513, 0.8436508 ],
#         [0.53911965, 0.02998026],
#         [0.27480752, 0.17666141],
#         [0.60194103, 0.03107791],
#         [0.96551101, 0.14507838],
#         [0.68693774, 0.05103604],
#         [0.43240132, 0.9019952 ],
#         [0.91890173, 0.18548248],
#         [0.93819557, 0.16434363],
#         [0.95011468, 0.54744578],
#         [0.88028336, 0.44017651],
#         [0.20191971, 0.57409144],
#         [0.43095951, 0.28158399],
#         [0.32119834, 0.18637486],
#         [0.02478956, 0.75323992],
#         [0.16246745, 0.89033076],
#         [0.10515854, 0.55639756],
#         [0.46341821, 0.57545918],
#         [0.59428451, 0.82252604]]),
#  '边界': array([0.99971494, 0.9019952 ]),
#  '纬度': 2,
#  '计算点数量': 30,
#  'a': 12,
#  '凸壳单面形成点的指数': array([[ 2, 25],
#         [15,  8],
#         [26, 25],
#         [20,  8],
#         [20,  6],
#         [13, 12],
#         [13,  2],
#         [16, 15],
#         [17,  6],
#         [17, 26],
#         [14, 12],
#         [14, 16]], dtype=int32),
#  '面积': 2.9348188049315,
#  '形成小面的超平面方程': array([[-0.98500818, -0.17250763,  0.15435756],
#         [ 0.78111331, -0.6243893 , -0.66358811],
#         [-0.70559441,  0.70861592, -0.51626643],
#         [ 0.99061991,  0.13664623, -1.01600892],
#         [ 0.67363603,  0.73906326, -1.04462854],
#         [-0.48524115, -0.87438037,  0.28781719],
#         [-0.64815595, -0.76150763,  0.31264714],
#         [ 0.31985151, -0.94746768, -0.17136307],
#         [ 0.26790429,  0.96344553, -0.98486541],
#         [-0.04317191,  0.99906766, -0.88248664],
#         [ 0.01746996, -0.99984739,  0.02055728],
#         [ 0.22859326, -0.97352202, -0.10734463]]),
#  '体积': 0.6178693080007558}

# %%
plt.plot(points[:,0], points[:,1], 'o')
# hull.vertices 得到凸轮廓坐标的索引值，逆时针画
hull1=hull.vertices.tolist()#要闭合必须再回到起点[0]
hull1.append(hull1[0])
plt.plot(points[hull1,0], points[hull1,1], 'r--^',lw=2)
for i in range(len(hull1)-1):
    plt.text(points[hull1[i],0], points[hull1[i],1],str(i),fontsize=20)
